# %% [markdown]
# ### Preliminary Analysis

# %%
import csv
with open('WEBPXTICK_DT-20260130.csv', mode ='r')as file:
  csvFile = csv.reader(file)

# %%
csvFile.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 csvFile.head()
#
# AttributeError: '_csv.reader' object has no attribute 'head'

# %%
import pandas as pd

df = pd.read_csv('WEBPXTICK_DT-20260130.csv')

print(df.head())
